# %%
import pandas as pd
from playwright.async_api import async_playwright
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless = False)
page = await browser.new_page()
from tqdm.notebook import tqdm
import time
import pdb
import csv
from PIL import Image
import requests
import pytesseract

# %%
url = 'https://services.ecourts.gov.in/ecourtindia_v6/?p=casestatus/index&app_token=c3c41da3cb5e335b69849006e4de6372a40dda722a50a46fd80a9086c896e86b'

# %%
await page.goto(url)
# Out:
# <Response url='https://services.ecourts.gov.in/ecourtindia_v6/?p=casestatus/index&app_token=c3c41da3cb5e335b69849006e4de6372a40dda722a50a46fd80a9086c896e86b' request=<Request url='https://services.ecourts.gov.in/ecourtindia_v6/?p=casestatus/index&app_token=c3c41da3cb5e335b69849006e4de6372a40dda722a50a46fd80a9086c896e86b' method='GET'>>

# %%
await page.locator('.alert-danger-cust').get_by_text('Select state, district and court complex to proceed further', exact=True).wait_for()
await page.locator('//*[@id="validateError"]/div/div/div[1]/button').click()

# %%
await page.locator('#sess_state_code').select_option('1')
# Out:
# ['1']

# %%
await page.locator('#sess_dist_code').select_option('27')
# Out:
# ['27']

# %% [markdown]
# ### Beed has three district courts: Beed, Ambajogai, and Majalgaon

# %%
#Beed
await page.locator('#court_complex_code').select_option('1010326@1,2,3@N')
#Ambajogai
#await page.locator('#court_complex_code').select_option('1010325@9@N')
#Majalgaon
#await page.locator('#court_complex_code').select_option('1010324@11,12,13@N')
# Out:
# ['1010326@1,2,3@N']

# %%
await page.locator('//*[@id="act-tabMenu"]').click()

# %%
await page.locator('#actcode').select_option('1')
# Out:
# ['1']

# %%
await page.locator('#under_sec').fill('302')

# %%
await page.locator('#radPAct').click()

# %%
captcha_image = await page.locator('#div_captcha_act #captcha_image').screenshot(type='png')

with open('captcha.png', 'wb') as fp:
    print("Saved as captcha.png")
    fp.write(captcha_image)
# Out:
# Saved as captcha.png

# %%
image = Image.open('captcha.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=121x46>

# %%
answer = pytesseract.image_to_string(image).strip()
answer
# Out:
# 'nfvkre'

# %%
await page.locator('#act_captcha_code').fill(answer)

# %%
await page.locator('//*[@id="frm_act"]/div[3]/div[2]/button').click()

# %%
table_1 = await page.query_selector_all('tr')

for row in table_1:
    print(await row.text_content())
# Out:
# Sr No
# 					Case Type/Case Number/Case Year
# 					Petitioner Name versus Respondent Name
# 					View
#
# District and Sessions Court , Beed
# 1
# 								Sessions Case/221/2022
# 								STATE OF MAHARASHATRAVsKrushna Alis Honda Shesherao Chavan
# 								View
#
# 2
# 								Sessions Case/211/2022
# 								STATE OF MAHARASHATRAVsSomeshwar Alis Abu Aellapa Shinde
# 								View
#
# 3
# 								Sessions Case/206/2022
# 								STATE OF MAHARASHATRAVsAkshay Alis Chintu Mitthau Gaikwad
# 								View
#
# 4
# 								Sessions Case/205/2022
# 								STATE OF MAHARASHATRAVsBabasaheb Dnyanob Tirgul
# 								View
#
# 5
# 								Sessions Case/199/2022
# 								STATE OF MAHARASHATRAVsShrikrushna Alis Bhayya Sakharam Baglane
# 								View
#
# 6
# 								Sessions Case/188/2022
# 								STATE OF MAHARASHATRAVsAmol Navnath Kale
# 								View
#
# 7
# 								Sessions Case/182/2022
# 								STATE OF MAHARASHATRAVsNarayan Bharat Pawar
# 								View
#
# 8
# 								Sessions Case/181/2022
# 								STATE OF MAHARASHATRAVsShahadev Alis Shahadya Vishwas Chavhan
# 								View
#
# 9
# 								Sessions Case/177/2022
# 								STATE OF MAHARASHATRAVsRohini Shahadev Chavhan
# 								View
#
# 10
# 								Sessions Case/175/2022
# 								STATE OF MAHARASHATRAVsSuraj Vishnu Bochare
# 								View
#
# 11
# 								Sessions Case/168/2022
# 								STATE OF MAHARASHATRAVsBabasaheb Alis Sanch Ahsok Waghule
# 								View
#
# 12
# 								Sessions Case/167/2022
# 								STATE OF MAHARASHATRAVsRameshwar Alis Lalu Anna Zite
# 								View
#
# 13
# 								Sessions Case/163/2022
# 								STATE OF MAHARASHATRAVsSimul Biswas Nrupdranath
# 								View
#
# 14
# 								Sessions Case/160/2022
# 								STATE OF MAHARASHATRAVsDinesh alias Vishvambar Pandurang Aabuj
# 								View
#
# 15
# 								Sessions Case/157/2022
# 								STATE OF MAHARASHATRAVsSidheshwar Alis Laxman Pandurang Bahrwal
# 								View
#
# 16
# 								Sessions Case/119/2022
# 								STATE OF MAHARASHATRAVsRaju Bhaurao Khildkar
# 								View
#
# 17
# 								Sessions Case/115/2022
# 								STATE OF MAHARASHATRAVsPralhad Navnath Ghumre
# 								View
#
# 18
# 								Sessions Case/109/2022
# 								STATE OF MAHARASHATRAVsBhagirath Ramkrushan Mishra
# 								View
#
# 19
# 								Sessions Case/108/2022
# 								STATE OF MAHARASHATRAVsPiraji Bajirao Shejul
# 								View
#
# 20
# 								Sessions Case/105/2022
# 								STATE OF MAHARASHATRAVsVaijanath Govindrao Domale
# 								View
#
# 21
# 								Sessions Case/103/2022
# 								STATE OF MAHARASHATRAVsMohansingh Hirasingh Tak Alis Sikkalkari
# 								View
#
# 22
# 								Sessions Case/100/2022
# 								STATE OF MAHARASHATRAVsChandrakant Nivrutti Salpe
# 								View
#
# 23
# 								Sessions Case/99/2022
# 								STATE OF MAHARASHATRAVsKapil Ramesh Joshi
# 								View
#
# 24
# 								Sessions Case/73/2022
# 								STATE OF MAHARASHATRAVsAngad Arjun Mundhe
# 								View
#
# 25
# 								Sessions Case/69/2022
# 								STATE OF MAHARASHATRAVsLaxman Ashruba Khatake
# 								View
#
# 26
# 								Sessions Case/50/2022
# 								STATE OF MAHARASHATRAVsUmesh Massa Waghmare
# 								View
#
# 27
# 								Sessions Case/31/2022
# 								STATE OF MAHARASHATRAVsMadan Pandurang Mangire
# 								View
#
# 28
# 								Sessions Case/26/2022
# 								STATE OF MAHARASHATRAVsShaikh Yakub Shaikh Khudbuddin
# 								View
#
# 29
# 								Sessions Case/201/2021
# 								STATE OF MAHARASHATRAVsMirabai Rajkumar Bade
# 								View
#
# 30
# 								Sessions Case/195/2021
# 								STATE OF MAHARASHATRAVsYogesh Mahadeo Aute
# 								View
#
# 31
# 								Sessions Case/184/2021
# 								STATE OF MAHARASHATRAVsSwami Ganesh Nagargoje
# 								View
#
# 32
# 								Sessions Case/174/2021
# 								STATE OF MAHARASHATRAVsRanjit Ankush Pawar
# 								View
#
# 33
# 								Sessions Case/165/2021
# 								STATE OF MAHARASHATRAVsKalyan Sonaba Khile
# 								View
#
# 34
# 								Sessions Case/162/2021
# 								STATE OF MAHARASHATRAVsParmeshwar Limba Salunke
# 								View
#
# 35
# 								Sessions Case/158/2021
# 								STATE OF MAHARASHATRAVsShivlal Rajendra Somwase
# 								View
#
# 36
# 								Sessions Case/146/2021
# 								STATE OF MAHARASHATRAVsBabasaheb Trimbak Khedkar
# 								View
#
# 37
# 								Sessions Case/138/2021
# 								STATE OF MAHARASHATRAVsRavindra Murlidhar Shinde
# 								View
#
# 38
# 								Sessions Case/137/2021
# 								STATE OF MAHARASHATRAVsNana alias Dnyaneshwar Appa Shinde
# 								View
#
# 39
# 								Sessions Case/132/2021
# 								STATE OF MAHARASHATRAVsDnyaneshwar alias Bhaiyya Shivaji Gaikwad
# 								View
#
# 40
# 								Sessions Case/110/2021
# 								STATE OF MAHARASHATRAVsMahadev Asaram Rede
# 								View
#
# 41
# 								Sessions Case/105/2021
# 								STATE OF MAHARASHATRAVsDevaibai Rohidas Sapkal
# 								View
#
# 42
# 								Sessions Case/91/2021
# 								STATE OF MAHARASHATRAVsKantilal Maruti Kakade
# 								View
#
# 43
# 								Sessions Case/58/2021
# 								STATE OF MAHARASHATRAVsMaharudra Machindra Paraskar
# 								View
#
# 44
# 								Sessions Case/41/2021
# 								STATE OF MAHARASHATRAVsAvinash Ramkisan Rajure
# 								View
#
# 45
# 								Sessions Case/24/2021
# 								STATE OF MAHARASHATRAVsParmeshwar Chagan Sasane
# 								View
#
# 46
# 								Sessions Case/9/2021
# 								STATE OF MAHARASHATRAVsUmesh Ashok Gade
# 								View
#
# 47
# 								Sessions Case/7/2021
# 								STATE OF MAHARASHATRAVsSantosh Jaydatta Kokane
# 								View
#
# 48
# 								Sessions Case/6/2021
# 								STATE OF MAHARASHATRAVsBandu Rama Pawar
# 								View
#
# 49
# 								Sessions Case/2/2021
# 								STATE OF MAHARASHATRAVsShahaji Shahattar Kale
# 								View
#
# 50
# 								Sessions Case/137/2020
# 								STATE OF MAHARASHATRAVsFaruk Ramjan Kureshi
# 								View
#
# 51
# 								Sessions Case/115/2020
# 								STATE OF MAHARASHATRAVsPandurang Kesu Chavan
# 								View
#
# 52
# 								Sessions Case/105/2020
# 								STATE OF MAHARASHATRAVsGanesh Ambadas Khedkar
# 								View
#
# 53
# 								Sessions Case/102/2020
# 								STATE OF MAHARASHATRAVsSachin Tukaram Kadam
# 								View
#
# 54
# 								Sessions Case/100/2020
# 								STATE OF MAHARASHATRAVsBaban Pandharinath Sul
# 								View
#
# 55
# 								Sessions Case/94/2020
# 								STATE OF MAHARASHATRAVsShaikh Nadim alias Nadya Shaikh Lalu
# 								View
#
# 56
# 								Sessions Case/93/2020
# 								STATE OF MAHARASHATRAVsRamesh Vaijinath Maske
# 								View
#
# 57
# 								Sessions Case/81/2020
# 								STATE OF MAHARASHATRAVsBalasaheb Bhagwan Dortale
# 								View
#
# 58
# 								Sessions Case/48/2020
# 								STATE OF MAHARASHATRAVsNitin Shankar Aware
# 								View
#
# 59
# 								Sessions Case/23/2020
# 								STATE OF MAHARASHATRAVsAynorya @ Ashok Indraya Bhosale
# 								View
#
# 60
# 								Sessions Case/18/2020
# 								STATE OF MAHARASHATRAVsArjun Mahadeo Mitkar
# 								View
#
# 61
# 								Sessions Case/311/2019
# 								STATE OF MAHARASHATRAVsRajabhau @ Omkar Sudhakar Kale
# 								View
#
# 62
# 								Sessions Case/261/2019
# 								STATE OF MAHARASHATRAVsArjun Dagdu Wani
# 								View
#
# 63
# 								Sessions Case/250/2019
# 								Usha Bharat ChaureVsRamesh Kothari
# 								View
#
# 64
# 								Sessions Case/248/2019
# 								STATE OF MAHARASHATRAVsKisan Kashinath Pawane
# 								View
#
# 65
# 								Sessions Case/234/2019
# 								STATE OF MAHARASHATRAVsJagdish Bhimrao Mote
# 								View
#
# 66
# 								Sessions Case/182/2019
# 								STATE OF MAHARASHATRAVsArjun Laxman Garje
# 								View
#
# 67
# 								Sessions Case/115/2019
# 								STATE OF MAHARASHATRAVsGadya Zarkya Chavan
# 								View
#
# 68
# 								Sessions Case/92/2019
# 								STATE OF MAHARASHATRAVsShahanoor Shidya @ Sandipan Kale
# 								View
#
# 69
# 								Sessions Case/89/2019
# 								STATE OF MAHARASHATRAVsRama Nawji Pawar
# 								View
#
# 70
# 								Sessions Case/67/2019
# 								STATE OF MAHARASHATRAVsDipak Laxman Garje
# 								View
#
# 71
# 								Sessions Case/35/2019
# 								STATE OF MAHARASHATRAVsVishnu Sadashiv Redekar
# 								View
#
# 72
# 								Sessions Case/120/2018
# 								STATE OF MAHARASHATRAVsRahul Lahu Ankushe
# 								View
#
# 73
# 								Sessions Case/104/2018
# 								STATE OF MAHARASHATRAVsShahadya Vishwas Chavan
# 								View
#
# 74
# 								Sessions Case/95/2018
# 								STATE OF MAHARASHATRAVsLaxman Vitthal Datal
# 								View
#
# 75
# 								Sessions Case/75/2018
# 								STATE OF MAHARASHATRAVsVipul Sitaram Jadhav
# 								View
#
# 76
# 								Sessions Case/32/2018
# 								STATE OF MAHARASHATRAVsAjit Ranglal Raka
# 								View
#
# 77
# 								Sessions Case/25/2018
# 								STATE OF MAHARASHATRAVsHaribhau @ Harichandra Dadasaheb Kharad
# 								View
#
# 78
# 								Sessions Case/12/2018
# 								STATE OF MAHARASHATRAVsVachista Ashruba Makhale
# 								View
#
# 79
# 								Sessions Case/11/2018
# 								STATE OF MAHARASHATRAVsAshok @ Pinya Namdev Kesbhat
# 								View
#
# 80
# 								Sessions Case/10/2018
# 								STATE OF MAHARASHATRAVsSoma Sheru Bhosale
# 								View
#
# 81
# 								Sessions Case/156/2017
# 								STATE OF MAHARASHATRAVsSadashiv Mahadev Umap
# 								View
#
# 82
# 								Sessions Case/153/2017
# 								STATE OF MAHARASHATRAVsShivaji Mahadev Fatak
# 								View
#
# 83
# 								Sessions Case/127/2017
# 								STATE OF MAHARASHATRAVsNagesh Balu Kothule
# 								View
#
# 84
# 								Sessions Case/108/2017
# 								STATE OF MAHARASHATRAVsRam @ Ramji Manohar Ghamat
# 								View
#
# 85
# 								Sessions Case/78/2017
# 								STATE OF MAHARASHATRAVsPandurang Sugriv Kothule
# 								View
#
# 86
# 								Sessions Case/16/2017
# 								STATE OF MAHARASHATRAVsGadya Zarkya Chavan
# 								View
#
# 87
# 								Sessions Case/13/2017
# 								STATE OF MAHARASHATRAVsMahadeo @ Ajay Ranuji Gholap
# 								View
#
# 88
# 								Sessions Case/131/2016
# 								STATE OF MAHARASHATRAVsEknath Chandrabhan Kurhade
# 								View
#
# 89
# 								Sessions Case/100026/2015
# 								The State of MaharashtraVsMahadeo Laxman Pawar
# 								View
#
# 90
# 								Sessions Case/100133/1996
# 								State of MaharashtraVsKachru Nivrutti Watmode
# 								View
#
# 91
# 								Spl.Case/116/2022
# 								STATE OF MAHARASHATRAVsDipak Santosh Bhore
# 								View
#
# 92
# 								Spl.Case/97/2022
# 								STATE OF MAHARASHATRAVsSonaji Sitaram Pache
# 								View
# 93
# 								Spl.Case/81/2022
# 								STATE OF MAHARASHATRAVsKhandu Rajendra Raut
# 								View
#
# 94
# 								Spl.Case/141/2021
# 								STATE OF MAHARASHATRAVsBaban Baburao Aute
# 								View
#
# 95
# 								Spl.Case/84/2020
# 								STATE OF MAHARASHATRAVsShridhar Ramesh Kale
# 								View
#
# 96
# 								Spl.Case/51/2020
# 								STATE OF MAHARASHATRAVsAnwarkhan alias Gujarkhan MirzaKhan
# 								View
#
# 97
# 								Spl.Case/13/2020
# 								STATE OF MAHARASHATRAVsBalasaheb Baburao Ombase
# 								View
#
# 98
# 								Cri.M.A./132/2022
# 								Lata Sahebrao KasbeVsSTATE OF MAHARASHATRA
# 								View
#
# 99
# 								Atro.Spl.Case/9/2019
# 								STATE OF MAHARASHATRAVsSonya @ Sagar @ Shaukat Jummalal Shaikh
# 								View
#
# 100
# 								Atro.Spl.Case/4/2019
# 								STATE OF MAHARASHATRAVsBalaji Sheshkumar Landge
# 								View
#
# 101
# 								Atro.Spl.Case/4/2018
# 								STATE OF MAHARASHATRAVsRushikesh Bhausaheb Lokhande
# 								View
#
# 102
# 								Cri.Bail Appln./1102/2022
# 								Shital Pandurang ChavanVsSTATE OF MAHARASHATRA
# 								View
#
# 103
# 								Spl.Case Child Prot./61/2019
# 								STATE OF MAHARASHATRAVsVikas Prabhakar Khandagale
# 								View
#
# 104
# 								Spl.Case Child Prot./25/2018
# 								STATE OF MAHARASHATRAVsAkanksha Manohar Dhere
# 								View
#
# Chief Judicial Magistrate , Beed
# 105
# 								Cri.M.A./1101/2017
# 								Shaikh Pasha Shaikh AllabakshVsShaikh Mahemood Shaikh Bade
# 								View
#
# 106
# 								Cri.M.A./300271/2003
# 								State of MaharashtraVsRajendra Annasaheb Karande
# 								View
#
# 107
# 								R.C.C./649/2022
# 								STATE OF MAHARASHTRAVsBandu Uttam Gavhane
# 								View
#
# 108
# 								R.C.C./582/2022
# 								STATE OF MAHARASHTRAVsBabasaheb Shivaji Chandane
# 								View
#
# 109
# 								R.C.C./300030/1971
# 								State of MaharashtraVsMustafakha  V. Umarkha
# 								View
#
# 110
# 								Juvenile/131/2022
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 111
# 								Juvenile/44/2022
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 112
# 								Juvenile/128/2021
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 113
# 								Juvenile/124/2021
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 114
# 								Juvenile/112/2021
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 115
# 								Juvenile/133/2019
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 116
# 								Juvenile/130/2019
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 117
# 								Juvenile/116/2019
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 118
# 								Juvenile/78/2019
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 119
# 								Juvenile/12/2019
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 120
# 								Juvenile/107/2018
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 121
# 								Juvenile/6/2018
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 122
# 								Juvenile/107/2016
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 123
# 								Juvenile/28/2016
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 124
# 								Juvenile/16/2016
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 125
# 								Juvenile/300102/2015
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 126
# 								Juvenile/300091/2015
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 127
# 								Juvenile/300045/2015
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 128
# 								Juvenile/300041/2015
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 129
# 								Juvenile/300029/2015
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 130
# 								Juvenile/300050/2014
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 131
# 								Juvenile/300002/2014
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 132
# 								Juvenile/300066/2013
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 133
# 								Juvenile/300042/2013
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 134
# 								Juvenile/300021/2013
# 								XXXXXXXVsXXXXXXX
# 								View
#
# 135
# 								Juvenile/300113/2012
# 								XXXXXXXVsXXXXXXX
# 								View

# %%
headers = ['case_id', 'case_title', 'court_name', ' Case Type', ' Filing Number ',
       'Registration Number', 'CNR Number', 'First Hearing Date',
       'Next Hearing Date', 'Case Stage', 'News and Events and Judge', 'Court Number and Judge',
       'Court Number and Name', 'Case Number and Year', 'Case Decision Date',
       'Police Station', 'FIR Number', 'Year', 'petitioner_and_advocate',
       'respondent_and_advocate','Case Transferred from Establishment', 'Transfer Date']

with open('BEED_pending_case_data.csv', 'w') as csvfile:
    writer = csv.writer(csvfile) # define a writer
    writer.writerow(headers) # write the row

# %%
# async def view_button_click_and_close_error_message(row):
#     view_button = await row.query_selector('a')
#     await view_button.click()
# #     print('clicked view button')
#     error_button = await page.query_selector('//*[@id="validateError"]/div/div/div[1]/button')
#     if error_button.is_visible():
#         await error_button.click()
# #         print('found error button')
#         raise Exception('error after clicking view')

# %% [markdown]
# # Function_1 scrape_weird_first_table()

# %%
async def scrape_weird_first_table(table):
    case_detail_table = {}
    all_trs = await table.query_selector_all('tr')
    for tr in all_trs:
        key_element = await tr.query_selector_all('td')
        key = await key_element[0].text_content()
        value_element = await tr.query_selector_all('td')
        value = await value_element[1].text_content()
        case_detail_table[key] = value
    return case_detail_table

# %% [markdown]
# # Function_2 scrape_side_by_side_table()

# %%
async def scrape_side_by_side_table(table):
    case_status_table = {}
    all_trs = await table.query_selector_all('tr')
    for tr in all_trs:
        all_tds = await tr.query_selector_all('td')
        if len(all_tds) == 2:
            left_column = await tr.query_selector_all('td')
            keys = await left_column[0].text_content()
            right_column = await tr.query_selector_all('td')
            values = await right_column[1].text_content()
            case_status_table[keys] = values
        else:
            pass
    return case_status_table

# %% [markdown]
# # Function_3 scrape_dataframe_style_table()

# %%
async def scrape_dataframe_style_table(table):
    tables = pd.read_html(await page.content())
    return tables[5]

# %% [markdown]
# # Scraping (Petitioner + Respondent) & Advocates
#
# ## petitioner_and_advocate_table
# #### Save all tds in form of a list and add the list as value to the result dictionary
# #### This will take care of pages where there are multiple tds which means multiple petitioners

# %%
petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
all_trs = await petitioner_and_advocate_table.query_selector_all('tr')
petitioner_advocate = {}
petitioner_and_advocate = []
for tr in all_trs:
    all_tds = await tr.query_selector_all('td')
    for td in all_tds:
        petitioner_and_advocate.append(await td.text_content())
        petitioner_advocate['petitioner_and_advocate'] = petitioner_and_advocate
    print(petitioner_advocate)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [23], line 2
#       1 petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
# ----> 2 all_trs = await petitioner_and_advocate_table.query_selector_all('tr')
#       3 petitioner_advocate = {}
#       4 petitioner_and_advocate = []
#
# AttributeError: 'NoneType' object has no attribute 'query_selector_all'

# %% [markdown]
# ## respondent_and_advocate_table
# #### Save all tds in form of a list and add the list as value to the result dictionary
# #### This will take care of pages where there are multiple tds which means multiple respondents

# %%
respondent_and_advocate_table = await page.query_selector('#CSact .Respondent_Advocate_table')
all_trs = await respondent_and_advocate_table.query_selector_all('tr')
respondent_advocate = {}
respondent_and_advocate = []
for tr in all_trs:
    all_tds = await tr.query_selector_all('td')
    for td in all_tds:
        respondent_and_advocate.append(await td.text_content())
        respondent_advocate['respondent_and_advocate'] = respondent_and_advocate
    print(respondent_advocate)

# %%
table_1 = await page.query_selector_all('tr')
index=0


for row in tqdm(table_1[1:]):
    index = index + 1
    list_of_cases = []
    each_case = {}
    all_tds = await row.query_selector_all('td')
    if len(all_tds) == 2:
        court_name = await all_tds[0].text_content()
    elif len(all_tds) == 4:
        case_id = await row.query_selector('td:nth-child(2)')
        case_title = await row.query_selector('td:nth-child(3)')
        each_case['case_id'] = (await case_id.text_content())
        each_case['case_title'] = (await case_title.text_content())
        each_case['court_name'] = court_name
    
        ###########################
        # if index==15:
        #    break # for debugging, delete later
        ###########################    

        already_scraped_df = pd.read_csv('BEED_pending_case_data.csv')
        already_scraped_case_ids = list(already_scraped_df['case_id'])
        if each_case['case_id'] in already_scraped_case_ids:
#             print(f"Already scraped {each_case['case_id']}")
            continue # this means go back to the top of the loop without finishing this iteration
        
        print(f"Scraping {each_case['case_id']}")
            
        time.sleep(3)
        
        #Because this case's view button acts weird, we are skipping this case
#         cases_to_skip = ['Sessions Case/100264/2014', 'Sessions Case/100919/2013', 'Sessions Case/100672/2013']
#         if each_case['case_id'] in cases_to_skip:
#             with open('BEED_pending_case_data.csv', 'a') as csvfile:
#                 writer = csv.DictWriter(csvfile, fieldnames=headers)
#                 writer.writerow(each_case)
#             list_of_cases.append(each_case)
#             continue
            
        #Click on view button
        view_button = await row.query_selector('a')
        await view_button.click()
            
        time.sleep(5)

        #Scrape the view contents and put them in each_case

        #case_details
        case_details_table = await page.query_selector('#CSact .case_details_table')
        case_details = await scrape_weird_first_table(case_details_table)
            #print(case_details)

        #case_status
        cases_status_table = await page.query_selector('#CSact .case_status_table')
        cases_status = await scrape_side_by_side_table(cases_status_table)
            #print(cases_status)

        #subordinate court
        lower_court_table = await page.query_selector('#CSact .Lower_court_table')
        if lower_court_table:
            lower_court = await scrape_side_by_side_table(lower_court_table)
        else:
            lower_court = {}
            print("Failed to scrape lower court table")
            #print(lower_court)

        #FIR_details
        FIR_details_table = await page.query_selector('#CSact .FIR_details_table')
        if FIR_details_table:
            FIR_details = await scrape_side_by_side_table(FIR_details_table)
        else:
            FIR_details = {}
            print("Failed to scrape FIR details table")
            #Put the result through pd.DataFrame() after looping
            #print(FIR_details)

        #petitioner_advocate
        petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
        all_trs = await petitioner_and_advocate_table.query_selector_all('tr')
        petitioner_advocate = {}
        petitioner_and_advocate = []
        for tr in all_trs:
            all_tds = await tr.query_selector_all('td')
            for td in all_tds:
                petitioner_and_advocate.append(await td.text_content())
                petitioner_advocate['petitioner_and_advocate'] = petitioner_and_advocate
                #print(petitioner_advocate)

        #respondent_advocate
        respondent_and_advocate_table = await page.query_selector('#CSact .Respondent_Advocate_table')
        all_trs = await respondent_and_advocate_table.query_selector_all('tr')
        respondent_advocate = {}
        respondent_and_advocate = []
        for tr in all_trs:
            all_tds = await tr.query_selector_all('td')
            for td in all_tds:
                respondent_and_advocate.append(await td.text_content())
                respondent_advocate['respondent_and_advocate'] = respondent_and_advocate
                #print(respondent_advocate)

        #click back button
        back_button = page.locator('#main_back_act')
        await back_button.click()
        
        time.sleep(5)
        
        all_case_data = {**each_case, **case_details, **cases_status, **lower_court, **FIR_details, **petitioner_advocate, **respondent_advocate}

        with open('BEED_pending_case_data.csv', 'a') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=headers)
            writer.writerow(all_case_data)
            
            
            
        list_of_cases.append(all_case_data)

    else:
        raise Exception("Error parsing table. Expected 2 or 4 td elements.")
# Out:
#   0%|          | 0/137 [00:00<?, ?it/s]
# Scraping Sessions Case/153/2017
# Failed to scrape lower court table
# Scraping Sessions Case/127/2017
# Scraping Sessions Case/108/2017
# Scraping Sessions Case/78/2017
# Scraping Sessions Case/16/2017
# Scraping Sessions Case/13/2017
# Scraping Sessions Case/131/2016
# Scraping Sessions Case/100026/2015
# Scraping Sessions Case/100133/1996
# Scraping Spl.Case/116/2022
# Failed to scrape lower court table
# Scraping Spl.Case/97/2022
# Failed to scrape lower court table
# Scraping Spl.Case/81/2022
# Failed to scrape lower court table
# Scraping Spl.Case/141/2021
# Failed to scrape lower court table
# Scraping Spl.Case/84/2020
# Failed to scrape lower court table
# Scraping Spl.Case/51/2020
# Failed to scrape lower court table
# Scraping Spl.Case/13/2020
# Failed to scrape lower court table
# Scraping Cri.M.A./132/2022
# Failed to scrape lower court table
# Scraping Atro.Spl.Case/9/2019
# Failed to scrape lower court table
# Scraping Atro.Spl.Case/4/2019
# Failed to scrape lower court table
# Scraping Atro.Spl.Case/4/2018
# Failed to scrape lower court table
# Scraping Cri.Bail Appln./1102/2022
# Failed to scrape lower court table
# Scraping Spl.Case Child Prot./61/2019
# Failed to scrape lower court table
# Scraping Spl.Case Child Prot./25/2018
# Failed to scrape lower court table
# Scraping Cri.M.A./1101/2017
# Failed to scrape lower court table
# Failed to scrape FIR details table
# Scraping Cri.M.A./300271/2003
# Failed to scrape lower court table
# Scraping R.C.C./649/2022
# Failed to scrape lower court table
# Scraping R.C.C./582/2022
# Failed to scrape lower court table
# Scraping R.C.C./300030/1971
# Failed to scrape lower court table
# Scraping Juvenile/131/2022
# Failed to scrape lower court table
# Scraping Juvenile/44/2022
# Failed to scrape lower court table
# Scraping Juvenile/128/2021
# Failed to scrape lower court table
# Scraping Juvenile/124/2021
# Failed to scrape lower court table
# Scraping Juvenile/112/2021
# Failed to scrape lower court table
# Scraping Juvenile/133/2019
# Failed to scrape lower court table
# Scraping Juvenile/130/2019
# Failed to scrape lower court table
# Scraping Juvenile/116/2019
# Failed to scrape lower court table
# Scraping Juvenile/78/2019
# Failed to scrape lower court table
# Scraping Juvenile/12/2019
# Failed to scrape lower court table
# Scraping Juvenile/107/2018
# Failed to scrape lower court table
# Scraping Juvenile/6/2018
# Failed to scrape lower court table
# Scraping Juvenile/107/2016
# Failed to scrape lower court table
# Scraping Juvenile/28/2016
# Failed to scrape lower court table
# Scraping Juvenile/16/2016
# Failed to scrape lower court table
# Scraping Juvenile/300102/2015
# Failed to scrape lower court table
# Scraping Juvenile/300091/2015
# Failed to scrape lower court table
# Scraping Juvenile/300045/2015
# Failed to scrape lower court table
# Scraping Juvenile/300041/2015
# Failed to scrape lower court table
# Scraping Juvenile/300029/2015
# Failed to scrape lower court table
# Scraping Juvenile/300050/2014
# Failed to scrape lower court table
# Scraping Juvenile/300002/2014
# Failed to scrape lower court table
# Scraping Juvenile/300066/2013
# Failed to scrape lower court table
# Scraping Juvenile/300042/2013
# Failed to scrape lower court table
# Scraping Juvenile/300021/2013
# Failed to scrape lower court table
# Scraping Juvenile/300113/2012
# Failed to scrape lower court table

# %% [markdown]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [26], line 45
#      34         #Because this case's view button acts weird, we are skipping this case
#      35 #         cases_to_skip = ['Sessions Case/100264/2014', 'Sessions Case/100919/2013', 'Sessions Case/100672/2013']
#      36 #         if each_case['case_id'] in cases_to_skip:
#    (...)
#      42
#      43         #Click on view button
#      44         view_button = await row.query_selector('a')
# ---> 45         await view_button.click()
#      47         time.sleep(5)
#      49         #Scrape the view contents and put them in each_case
#      50
#      51         #case_details
#
# AttributeError: 'NoneType' object has no attribute 'click'
#
#
# # This error occured after the entire list of 74 was done. Then it tried to scrape more and the tqdm counter said it was looking for 104 even though there were only 74 on the page.

# %%
data_so_far = pd.read_csv('pending_case_data.csv')
data_so_far.to_csv(f'pending_case_data_{pd.Timestamp.now()}.csv')

# %%
#df.to_csv('MAH_pending_302.csv', index=False)

# %%
#pd.read_csv('MAH_pending_302.csv')

# %%
#SAFEKEEPING

# view_button = await page.locator('//*[@id="dispTable"]/tbody/tr[2]/td[4]/a').click()
# #case_details
# case_details_table = await page.query_selector('#CSact .case_details_table')
# case_details = await scrape_weird_first_table(case_details_table)
# print(case_details)

# #case_status
# cases_status_table = await page.query_selector('#CSact .case_status_table')
# cases_status = await scrape_side_by_side_table(cases_status_table)
# print(cases_status)

# #subordinate court
# lower_court_table = await page.query_selector('#CSact .Lower_court_table')
# lower_court = await scrape_side_by_side_table(lower_court_table)
# print(lower_court)

# #FIR_details
# FIR_details_table = await page.query_selector('#CSact .FIR_details_table')
# FIR_details = await scrape_side_by_side_table(FIR_details_table)
# #Put the result through pd.DataFrame() after looping
# print(FIR_details)

# #petitioner_advocate
# petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
# all_trs = await petitioner_and_advocate_table.query_selector_all('tr')
# petitioner_advocate = {}
# petitioner_and_advocate = []
# for tr in all_trs:
#     all_tds = await tr.query_selector_all('td')
#     for td in all_tds:
#         petitioner_and_advocate.append(await td.text_content())
#         petitioner_advocate['petitioner_and_advocate'] = petitioner_and_advocate
#     print(petitioner_advocate)
    
# #respondent_advocate
# respondent_and_advocate_table = await page.query_selector('#CSact .Respondent_Advocate_table')
# all_trs = await respondent_and_advocate_table.query_selector_all('tr')
# respondent_advocate = {}
# respondent_and_advocate = []
# for tr in all_trs:
#     all_tds = await tr.query_selector_all('td')
#     for td in all_tds:
#         respondent_and_advocate.append(await td.text_content())
#         respondent_advocate['respondent_and_advocate'] = respondent_and_advocate
#     print(respondent_advocate)

# %%
#back_button = await page.locator('//*[@id="main_back_act"]').click()

# %%
#List of tables for reference and mental health

# case_details_table = await page.query_selector('#CSact .case_details_table')
# cases_status_table = await page.query_selector('#CSact .case_status_table')
# petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
# respondent_and_advocate_table = await page.query_selector('#CSact .Respondent_Advocate_table')
# acts_table = await page.query_selector('#CSact .acts_table')
# lower_court_table = await page.query_selector('#CSact .Lower_court_table')
# FIR_details_table = await page.query_selector('#CSact .FIR_details_table')

# %%
# collect dictionaries for each table
# case_details_data = scrape_weird_first_table(case_details_table)
# case_status_data = scrape_side_by_side_table(case_status_table)

# # combine dictionaries
# case_data = {**case_details_data, **case_status_data}

# %% [markdown]
# ### case_details_table

# %%
case_details_table = await page.query_selector('#CSact .case_details_table')
case_details = await scrape_weird_first_table(case_details_table)
print(case_details)

# %% [markdown]
# ### cases_status_table

# %%
cases_status_table = await page.query_selector('#CSact .case_status_table')
cases_status = await scrape_side_by_side_table(cases_status_table)
print(cases_status)

# %% [markdown]
# ### lower_court_table

# %%
lower_court_table = await page.query_selector('#CSact .Lower_court_table')
lower_court = await scrape_side_by_side_table(lower_court_table)
print(lower_court)

# %% [markdown]
# ### FIR_details_table

# %%
FIR_details_table = await page.query_selector('#CSact .FIR_details_table')
FIR_details = await scrape_side_by_side_table(FIR_details_table)
#Put the result through pd.DataFrame() after looping
print(FIR_details)

# %% [markdown]
# ### acts_table

# %%
acts_table = await page.query_selector('#CSact .acts_table')
acts = await scrape_dataframe_style_table(acts_table)
print(acts)

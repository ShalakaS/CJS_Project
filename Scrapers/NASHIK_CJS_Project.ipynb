# %%
import pandas as pd
from playwright.async_api import async_playwright
playwright = await async_playwright().start()
browser = await playwright.chromium.launch(headless = False)
page = await browser.new_page()
from tqdm.notebook import tqdm
import time
import pdb
import csv
from PIL import Image
import requests
import pytesseract

# %%
url = 'https://services.ecourts.gov.in/ecourtindia_v6/?p=casestatus/index&app_token=c3c41da3cb5e335b69849006e4de6372a40dda722a50a46fd80a9086c896e86b'

# %%
await page.goto(url)
# Out:
# <Response url='https://services.ecourts.gov.in/ecourtindia_v6/?p=casestatus/index&app_token=c3c41da3cb5e335b69849006e4de6372a40dda722a50a46fd80a9086c896e86b' request=<Request url='https://services.ecourts.gov.in/ecourtindia_v6/?p=casestatus/index&app_token=c3c41da3cb5e335b69849006e4de6372a40dda722a50a46fd80a9086c896e86b' method='GET'>>

# %%
await page.locator('.alert-danger-cust').get_by_text('Select state, district and court complex to proceed further', exact=True).wait_for()
await page.locator('//*[@id="validateError"]/div/div/div[1]/button').click()

# %%
await page.locator('#sess_state_code').select_option('1')
# Out:
# ['1']

# %%
await page.locator('#sess_dist_code').select_option('20')
# Out:
# ['20']

# %% [markdown]
# ### Nashik, Niphad, and Malegaon are three district courts in Nashik district

# %%
#NASHIK: 
#await page.locator('#court_complex_code').select_option('1010245@1,2,3,4,24@N')
#Niphad: 
#await page.locator('#court_complex_code').select_option('1010243@7,16@N')
#Malegaon:
await page.locator('#court_complex_code').select_option('1010241@9,10@N')
# Out:
# ['1010241@9,10@N']

# %%
await page.locator('//*[@id="act-tabMenu"]').click()

# %%
await page.locator('#actcode').select_option('1')
# Out:
# ['1']

# %%
await page.locator('#under_sec').fill('302')

# %%
await page.locator('#radPAct').click()

# %%
captcha_image = await page.locator('#div_captcha_act #captcha_image').screenshot(type='png')

with open('captcha.png', 'wb') as fp:
    print("Saved as captcha.png")
    fp.write(captcha_image)
# Out:
# Saved as captcha.png

# %%
image = Image.open('captcha.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=121x46>

# %%
answer = pytesseract.image_to_string(image).strip()
answer
# Out:
# '96r7ft'

# %%
await page.locator('#act_captcha_code').fill(answer)

# %%
await page.locator('//*[@id="frm_act"]/div[3]/div[2]/button').click()

# %%
table_1 = await page.query_selector_all('tr')

for row in table_1:
    print(await row.text_content())
# Out:
# Sr No
# 					Case Type/Case Number/Case Year
# 					Petitioner Name versus Respondent Name
# 					View
#
# District Court-1 ,Malegaon
# 1
# 								Sessions Case/187/2022
# 								State Thr Wadner Khakurdi Police StnVsShubham @ Bablu Suresh Pawar
# 								View
#
# 2
# 								Sessions Case/175/2022
# 								State Thr Nandgaon Police StnVsSamadhan Daulat Bhad
# 								View
#
# 3
# 								Sessions Case/173/2022
# 								State Thr Dyane Ramjanpura Police StnVsRekha Sunil Chavhan
# 								View
#
# 4
# 								Sessions Case/169/2022
# 								State Thr Pawarwadi Police Stn, MalegaonVsAbdul Rehman Shaikh Shakoor @ Papa
# 								View
#
# 5
# 								Sessions Case/159/2022
# 								State Thr Pawarwadi Police Stn, MalegaonVsAbujar Mohammad Israil
# 								View
#
# 6
# 								Sessions Case/146/2022
# 								State Thr Nandgaon Police StnVsSanjay Somnath Dive
# 								View
#
# 7
# 								Sessions Case/140/2022
# 								State Thr Nandgaon Police StnVsGovinda Waluba Keskar
# 								View
#
# 8
# 								Sessions Case/129/2022
# 								State Thr Manmad City Police Stn.VsShobha Bhagwan Garudkar
# 								View
#
# 9
# 								Sessions Case/124/2022
# 								State Thr Satana Police StationVsHiraman Namdeo Pawar
# 								View
#
# 10
# 								Sessions Case/122/2022
# 								State Thr Malegaon Taluka Police StnVsRohini Dipak Suryawanshi
# 								View
#
# 11
# 								Sessions Case/116/2022
# 								State Thr Pawarwadi Police Stn, MalegaonVsMohammad Imran Usman Gani
# 								View
#
# 12
# 								Sessions Case/67/2022
# 								State Thr Malegaon Taluka Police StnVsArchana Nana Khairnar @ Mai Sandip Khairnar
# 								View
#
# 13
# 								Sessions Case/66/2022
# 								State Thr Malegaon Taluka Police StnVsAkash Subhash Jagtap
# 								View
#
# 14
# 								Sessions Case/41/2022
# 								State Thr Manmad Railway Police StnVsMohit Rajesh Sukheja
# 								View
#
# 15
# 								Sessions Case/23/2022
# 								State Thr Nandgaon Police StnVsSandip @ Pinu Vijaysingh Borse @ Patil
# 								View
#
# 16
# 								Sessions Case/22/2022
# 								State Thr Pawarwadi Police Stn, MalegaonVsSaman Khan Hamid Khan
# 								View
#
# 17
# 								Sessions Case/185/2021
# 								State Thr. Azadnagar Police Stn, MalegaonVsFaizan Akhtar Abdul Raheman shaikh
# 								View
#
# 18
# 								Sessions Case/178/2021
# 								State Thr Satana Police StationVsHiraman Kalu Wagh
# 								View
#
# 19
# 								Sessions Case/177/2021
# 								State Thr Satana Police StationVsVikram Dodha Pawar
# 								View
#
# 20
# 								Sessions Case/175/2021
# 								State Thr. Ayeshanagar Police Stn MalegaonVsAshpak Ahmad @ Chongya Rais Ahmad
# 								View
#
# 21
# 								Sessions Case/165/2021
# 								State Thr Satana Police StationVsSanjay Zipru Pawar
# 								View
#
# 22
# 								Sessions Case/163/2021
# 								State Thr Manmad City Police Stn.VsDurga Shankarlal Prasad @ Jagdish @ Jaggu Dada
# 								View
#
# 23
# 								Sessions Case/160/2021
# 								State Thr Satana Police StationVsNamdeo Baburao Khandvi
# 								View
#
# 24
# 								Sessions Case/158/2021
# 								State Thr Pawarwadi Police Stn, MalegaonVsHasim Harun Pinjari @ Papa Golden
# 								View
#
# 25
# 								Sessions Case/157/2021
# 								State Thr Malegaon Taluka Police StnVsSagar Rajendra Ingale
# 								View
#
# 26
# 								Sessions Case/119/2021
# 								State Thr Manmad City Police Stn.VsNamdeo Shamrao Ahire
# 								View
#
# 27
# 								Sessions Case/116/2021
# 								State Thr Pawarwadi Police Stn, MalegaonVsSadik Shaikh Latif @ Pappu
# 								View
#
# 28
# 								Sessions Case/115/2021
# 								State Thr Malegaon City Police StnVsRahim Shaikh
# 								View
#
# 29
# 								Sessions Case/81/2021
# 								State Thr. Azadnagar Police Stn, MalegaonVsMasood Akhtar Abdul Malik
# 								View
#
# 30
# 								Sessions Case/78/2021
# 								State Thr. Camp Police Stn, MalegaonVsRupesh Nandu Thakare
# 								View
#
# 31
# 								Sessions Case/49/2021
# 								State Thr Pawarwadi Police Stn, MalegaonVsReshma Bano Abdul Majid Ansari
# 								View
#
# 32
# 								Sessions Case/48/2021
# 								State Thr Killa Police Stn, MalegaonVsMohammad Yusuf Mohammad Yakub @ Yusuf Bhurya
# 								View
#
# 33
# 								Sessions Case/46/2021
# 								State of MaharashtraVsSunil Shivaji More
# 								View
#
# 34
# 								Sessions Case/28/2021
# 								State Thr Wadner Khakurdi Police StnVsSagar Damu Khairnar
# 								View
#
# 35
# 								Sessions Case/21/2021
# 								State Thr Pawarwadi Police Stn, MalegaonVsIstiyak Ahemad Khalil Ahemad @ Laddu Dada
# 								View
#
# 36
# 								Sessions Case/20/2021
# 								State Thr. Azadnagar Police Stn, MalegaonVsKazi Irfan Ahemad Salauddin @ Ippu
# 								View
#
# 37
# 								Sessions Case/18/2021
# 								State Thr Satana Police StationVsHarshada Arun Sonawaen
# 								View
#
# 38
# 								Sessions Case/8/2021
# 								State Thr Dyane Ramjanpura Police StnVsShahrukh Shah Daud Shah
# 								View
#
# 39
# 								Sessions Case/158/2020
# 								State of MaharashtraVsShaikh Arif Abdul Rashid
# 								View
#
# 40
# 								Sessions Case/151/2020
# 								State Thr Jaikheda Police Stn, SatanaVsJankabai Supadu Padalkar
# 								View
#
# 41
# 								Sessions Case/142/2020
# 								State Thr Jaikheda Police Stn, SatanaVsKedarnath Bhika Pawar Death
# 								View
#
# 42
# 								Sessions Case/139/2020
# 								State Thr Wadner Khakurdi Police StnVsManoj Bhatu Dongare
# 								View
#
# 43
# 								Sessions Case/134/2020
# 								State Thr Pawarwadi Police Stn, MalegaonVsMohammad Jabir Iqbal Ahemad @ Atank @ Osama
# 								View
#
# 44
# 								Sessions Case/120/2020
# 								State Thr Nandgaon Police StnVsBandu Nivrutti Hilam
# 								View
#
# 45
# 								Sessions Case/108/2020
# 								State Thr Nandgaon Police StnVsGullu @ Dullu Shaikh @ Mondal Yunus Shaikh
# 								View
#
# 46
# 								Sessions Case/211/2019
# 								State Thr Nandgaon Police StnVsGufran Shafi Shaikh
# 								View
#
# 47
# 								Sessions Case/123/2019
# 								State Thr Wadner Khakurdi Police StnVsSamadhan Dadaji Dhivre
# 								View
#
# 48
# 								Sessions Case/60/2019
# 								State Thr. Chavani Police Stn MalegaonVsDnyaneshwar Prakash Borse
# 								View
#
# 49
# 								Sessions Case/59/2019
# 								State Thr Pawarwadi Police Stn, Malegaon (UTP)VsMo. Kasim Mukim Ahemad
# 								View
#
# 50
# 								Sessions Case/15/2019
# 								State Thr Manmad City Police Stn.VsIlias Ismail Sayyed
# 								View
#
# 51
# 								Sessions Case/13/2019
# 								State Thr. Chavani Police Stn MalegaonVsSharad Sakharam Chaudhari
# 								View
#
# 52
# 								Sessions Case/12/2019
# 								State Thr Wadner Khakurdi Police StnVsTanaji Suka Mali (bail)
# 								View
#
# 53
# 								Sessions Case/7/2019
# 								State Thr Wadner Khakurdi Police StnVsSanjay Motiram Pawar
# 								View
#
# 54
# 								Sessions Case/166/2018
# 								State Thr Nandgaon Police StnVsShaikh Yusuf Shaikh Kadar ( Maniyar) ,5
# 								View
#
# 55
# 								Sessions Case/158/2018
# 								State Thr Manmad City Police Stn.VsPapa @ Vinod Madhukar Karosiya , 3
# 								View
#
# 56
# 								Sessions Case/153/2018
# 								State Thr Satana Police StationVsVikas Bapu Wagh , 1
# 								View
#
# 57
# 								Sessions Case/147/2018
# 								State Thr Malegaon City Police StnVsLiyakat Ali Yusuf Ali , 2
# 								View
#
# 58
# 								Sessions Case/130/2018
# 								State Thr Nandgaon Police StnVsDyaneshwar @ Panjab Kashinath Kale
# 								View
#
# 59
# 								Sessions Case/128/2018
# 								State Thr Manmad City Police Stn.VsBhagwan Jagannath Solanke
# 								View
#
# 60
# 								Sessions Case/111/2018
# 								State Thr Malegaon City Police StnVsShoaib Shahanawaj Mansuri , 4
# 								View
#
# 61
# 								Sessions Case/109/2018
# 								State Thr Malegaon Taluka Police StnVsRupesh @ Bhurya Suresh Patil , 2
# 								View
#
# 62
# 								Sessions Case/107/2018
# 								State Thr Malegaon Taluka Police StnVsSurmi Bharsing Garve
# 								View
#
# 63
# 								Sessions Case/105/2018
# 								State Thr Pawarwadi Police Stn, MalegaonVsShaikh Raees Shaikh Rashid , 2
# 								View
#
# 64
# 								Sessions Case/60/2018
# 								State Thr Satana Police StationVsPratap Rupsing Datre
# 								View
#
# 65
# 								Sessions Case/59/2018
# 								State Thr Manmad City Police Stn.VsKishor Mahadev Wankhede
# 								View
#
# 66
# 								Sessions Case/47/2018
# 								State Thr Nandgaon Police StnVsVasant @ Kalu Suklal Rathod
# 								View
#
# 67
# 								Sessions Case/46/2018
# 								State Thr Nandgaon Police StnVsRavindra Popat Bagul
# 								View
#
# 68
# 								Sessions Case/38/2018
# 								State Thr Nandgaon Police StnVsPopat Pundlik Jadhav
# 								View
#
# 69
# 								Sessions Case/12/2018
# 								Dyane Ramjanpura Police Stn, MalegaonVsEhsan Ali Siddhiqui vald Fakir Mohamamd Alias Virappan
# 								View
#
# 70
# 								Sessions Case/8/2018
# 								Jaikheda Police Stn, SatanaVsAnanda Tukaram Sonawane
# 								View
#
# 71
# 								Sessions Case/166/2017
# 								Manmad City Police Stn ManmadVsSantosh Fakirrao Mali
# 								View
#
# 72
# 								Sessions Case/153/2017
# 								Taluka Police Stn. MalegaonVsSuresh Walmik Nikam Etc 2
# 								View
#
# 73
# 								Sessions Case/126/2017
# 								Taluka Police Stn. MalegaonVsLaxman Haribhau Chormale
# 								View
#
# 74
# 								Sessions Case/121/2017
# 								Pawarwadi Police Stn, MalegaonVsBibi Laeel Ali Sayyed
# 								View
#
# 75
# 								Sessions Case/112/2017
# 								State Satana Police Stn SatanaVsKalu Uttam Sonawane
# 								View
#
# 76
# 								Sessions Case/96/2017
# 								State Malegaon Taluka Police Stn. MalegaonVsDigambar Gobaji Ahire
# 								View
#
# 77
# 								Sessions Case/84/2017
# 								Malegaon Killa Police StationVsKhalil Ahmed Nihal Ahmed @ Khalla
# 								View
#
# 78
# 								Sessions Case/60/2017
# 								Malegaon Taluka Police StationVsPrashant Gangadhar Kadam etc 4
# 								View
#
# 79
# 								Sessions Case/50/2017
# 								Manmad City Police StationVsMahendra Nimba Sonawne
# 								View
#
# 80
# 								Sessions Case/31/2017
# 								State Through Nandgaon PstVsRahul Dilip Gadhakh
# 								View
#
# 81
# 								Sessions Case/23/2017
# 								State Through Malegaon City PstVsHamid Ahmed Shabbir Ahmed
# 								View
#
# 82
# 								Sessions Case/17/2017
# 								State of Maharashtra Through Chavani Police Station MalegaonVsJagannath alias Lalit Nimba Kadam etc 1
# 								View
#
# 83
# 								Sessions Case/120/2016
# 								State Through Taluka Police StationVsVinod Mahadu Pawar
# 								View
#
# 84
# 								Sessions Case/111/2016
# 								State Through Taluka Police Station MalegaonVsSatish Bhausaheb Pawar
# 								View
#
# 85
# 								Sessions Case/108/2016
# 								State Through Jaykheda Police StationVsMirabai Ravindra Jadhav Etc
# 								View
#
# 86
# 								Sessions Case/7/2016
# 								Ayeshanagar Police StaionVsVishal @ Ravindra Tatyasaheb Ahire
# 								View
#
# 87
# 								Sessions Case/800147/2015
# 								The State of Maharashtra Through City police Station MalegaonVsBharat Dnyaneshwar Sonawane etc. 3
# 								View
#
# 88
# 								Sessions Case/800100/2015
# 								StateVsShaikh Harun Shaikh Nasir
# 								View
#
# 89
# 								Sessions Case/800021/2015
# 								stateVsTrimbak Kashiram Ahire etc. 3
# 								View
#
# 90
# 								Sessions Case/800108/2014
# 								State Chhavani Police Station, malegaonVsManoj Sukdeo Ghute etc 1
# 								View
#
# 91
# 								Sessions Case/800101/2014
# 								State Jaikheda Police station,VsDadaji Namdeo Ahire
# 								View
#
# 92
# 								Sessions Case/800064/2014
# 								The State of MaharashtraVs1.Meenabai Raosheab-Chhotu Kadam,etc.1
# 								View
#
# 93
# 								Sessions Case/800040/2014
# 								State 302 Satana Police Station, SatanaVsPintya Bhavrao Arjun Bagul etc 3
# 								View
#
# 94
# 								Sessions Case/800030/2014
# 								State of MaharashtraVsAbdul Rehman Abid Husen etc,3
# 								View
#
# 95
# 								Sessions Case/800135/2013
# 								State of Maharashtra,us.302VsSadu Ramji Hilam
# 								View
#
# 96
# 								Sessions Case/800060/2013
# 								State Us.302,307VsMohd. Mehetab Shaukat Ali etc.7
# 								View
#
# 97
# 								Sessions Case/800024/2012
# 								State Thr Satana Police Station IPC 302 UTPVsAbhimanyu Keda Bagul
# 								View
#
# 98
# 								Sessions Case/800007/2012
# 								StateVsMajja Dada@ Majid Husen Vajid Husain.4
# 								View
#
# 99
# 								Sessions Case/800104/2011
# 								State of MH Chavnani Police St.VsDipak Sunil Gaikwad.4.
# 								View
#
# 100
# 								Sessions Case/800018/2011
# 								StateVsRizwan Kureshi @ Sonu Suleman Kureshi.
# 								View
#
# 101
# 								Sessions Case/800071/2010
# 								stateVsAbscond. Shaikh Fakruddin (frutwala, Bhajiwala).
# 								View
#
# 102
# 								Sessions Case/800023/2010
# 								State of MH Azhadnagar P.SVsFaridabano Atik Ahemad Ansari
# 								View
#
# 103
# 								Sessions Case/800099/2009
# 								State Thr Killa Police Stn, MalegaonVsMohammad Alamgir Azamkhan @ Amir Azam Mohd. Azamkh
# 								View
#
# 104
# 								Sessions Case/800025/2008
# 								StateVsValmik T.Sonawane-2
# 								View
#
# 105
# 								Sessions Case/800107/2003
# 								State of MaharashtraVsSatyanarayan Ramchandra Sharama etc.1
# 								View
#
# 106
# 								Sessions Case/800090/2002
# 								State302VsBalu Gangaram Mali.
# 								View
#
# 107
# 								Sessions Case/800041/1997
# 								stateVsNanaji Pira Pawar alias Nanaji Sakharam More.
# 								View
# 108
# 								Spl.Case/46/2022
# 								State Thr Malegaon Taluka Police StnVsSachin @ Sanjay @ Bongya @ Ravi @ Dharma @ Sakhahari @ Sakharam Chavhan
# 								View
#
# 109
# 								Cri.Rev.App./29/2022
# 								Taufeeuqe Akhtar Abdul MalikVsState of Maharashtra
# 								View
#
# 110
# 								Cri.Rev.App./77/2019
# 								Sadam Badshah AktarVsLocal Crime branch Nashik Rural
# 								View
#
# 111
# 								Cri.M.A./25/2022
# 								Ratnabai Ramdas ThakareVsSonu Vasant Borse
# 								View
#
# 112
# 								Cri.M.A./50/2021
# 								Dadalal Shankar PatilVsRajendra Amrut Kapgate
# 								View
#
# 113
# 								Atro.Spl.Case/28/2020
# 								State Thr Wadner Khakurdi Police StnVsUmesh  Prakash Patil
# 								View
#
# 114
# 								Atro.Spl.Case/7/2017
# 								State Through Satana Police StationVsDattatray Tanaji Gunjal
# 								View
#
# 115
# 								Cri.Bail Appln./642/2022
# 								Nasir Khan Ayub KhanVsState Thr. Azadnagar Police Stn, Malegaon
# 								View
#
# 116
# 								Cri.Bail Appln./641/2022
# 								Abdul Samad Zakir HusainVsState Thr Dyane Ramjanpura Police Stn
# 								View
#
# 117
# 								Cri.Bail Appln./638/2022
# 								Zafarullah Khan Amanullah Khan @ Zafar PahelwanVsState Thr. Azadnagar Police Stn, Malegaon
# 								View
#
# 118
# 								Cri.Bail Appln./588/2022
# 								Gaurav Dadabhai HadapVsState Thr Malegaon Taluka Police Stn
# 								View
#
# Civil Court Senior Division ,Malegaon
# 119
# 								Cri.M.A./1324/2021
# 								Nirmala Ashok DeoreVsMohan Kautik Deore
# 								View
#
# 120
# 								Cri.M.A./5699/2020
# 								Hiraman Lalchand SonwaneVsPandit Kashinath Ahire
# 								View
#
# 121
# 								Cri.M.A./1000033/2003
# 								StateVsLahu Mahadu Sonwane
# 								View
#
# 122
# 								R.C.C./782/2022
# 								State Thro. Pawarwadi Police St., MalegaonVsTausif Ahmed Rafik Ahmed @ Raju
# 								View
#
# 123
# 								R.C.C./704/2022
# 								State Thro. Azadnagar Police St., MalegaonVsAfajal    Khan Gulsher Khan Other 5
# 								View
#
# 124
# 								R.C.C./693/2022
# 								State Thro. Dyane Ramjanpura Police St., MalegaonVsAbdul Wafa Abdul Raheman
# 								View
#
# 125
# 								R.C.C./364/2022
# 								State Thro. Malegaon City Police St., MalegaonVsRaiees Ahmad Saieed  Ahmad
# 								View
#
# 126
# 								R.C.C./695/2021
# 								State Thro. Dyane Ramjanpura Police St., MalegaonVsJamal Anjum Mohammd Ayub
# 								View
#
# 127
# 								R.C.C./84/2020
# 								State Thro. Chhavani Police St., MalegaonVsMohammad Yusuf Mohammad Yakub urf Yusuf Bhurya and 2
# 								View

# %%
headers = ['case_id', 'case_title', 'court_name', ' Case Type', ' Filing Number ',
       'Registration Number', 'CNR Number', 'First Hearing Date',
       'Next Hearing Date', 'Case Stage', 'News and Events and Judge', 'Court Number and Judge',
       'Court Number and Name', 'Case Number and Year', 'Case Decision Date',
       'Police Station', 'FIR Number', 'Year', 'petitioner_and_advocate',
       'respondent_and_advocate','Case Transferred from Establishment', 'Transfer Date']

with open('NASHIK_MALEGAON_pending_case_data.csv', 'w') as csvfile:
    writer = csv.writer(csvfile) # define a writer
    writer.writerow(headers) # write the row

# %% [markdown]
# # Function_1 scrape_weird_first_table()

# %%
async def scrape_weird_first_table(table):
    case_detail_table = {}
    all_trs = await table.query_selector_all('tr')
    for tr in all_trs:
        key_element = await tr.query_selector_all('td')
        key = await key_element[0].text_content()
        value_element = await tr.query_selector_all('td')
        value = await value_element[1].text_content()
        case_detail_table[key] = value
    return case_detail_table

# %% [markdown]
# # Function_2 scrape_side_by_side_table()

# %%
async def scrape_side_by_side_table(table):
    case_status_table = {}
    all_trs = await table.query_selector_all('tr')
    for tr in all_trs:
        all_tds = await tr.query_selector_all('td')
        if len(all_tds) == 2:
            left_column = await tr.query_selector_all('td')
            keys = await left_column[0].text_content()
            right_column = await tr.query_selector_all('td')
            values = await right_column[1].text_content()
            case_status_table[keys] = values
        else:
            pass
    return case_status_table

# %% [markdown]
# # Function_3 scrape_dataframe_style_table()

# %%
async def scrape_dataframe_style_table(table):
    tables = pd.read_html(await page.content())
    return tables[5]

# %% [markdown]
# # Scraping (Petitioner + Respondent) & Advocates
#
# ## petitioner_and_advocate_table
# #### Save all tds in form of a list and add the list as value to the result dictionary
# #### This will take care of pages where there are multiple tds which means multiple petitioners

# %%
# petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
# all_trs = await petitioner_and_advocate_table.query_selector_all('tr')
# petitioner_advocate = {}
# petitioner_and_advocate = []
# for tr in all_trs:
#     all_tds = await tr.query_selector_all('td')
#     for td in all_tds:
#         petitioner_and_advocate.append(await td.text_content())
#         petitioner_advocate['petitioner_and_advocate'] = petitioner_and_advocate
#     print(petitioner_advocate)

# %% [markdown]
# ## respondent_and_advocate_table
# #### Save all tds in form of a list and add the list as value to the result dictionary
# #### This will take care of pages where there are multiple tds which means multiple respondents

# %%
# respondent_and_advocate_table = await page.query_selector('#CSact .Respondent_Advocate_table')
# all_trs = await respondent_and_advocate_table.query_selector_all('tr')
# respondent_advocate = {}
# respondent_and_advocate = []
# for tr in all_trs:
#     all_tds = await tr.query_selector_all('td')
#     for td in all_tds:
#         respondent_and_advocate.append(await td.text_content())
#         respondent_advocate['respondent_and_advocate'] = respondent_and_advocate
#     print(respondent_advocate)

# %%
table_1 = await page.query_selector_all('tr')
index=0


for row in tqdm(table_1[1:]):
    index = index + 1
    list_of_cases = []
    each_case = {}
    all_tds = await row.query_selector_all('td')
    if len(all_tds) == 2:
        court_name = await all_tds[0].text_content()
    elif len(all_tds) == 4:
        case_id = await row.query_selector('td:nth-child(2)')
        case_title = await row.query_selector('td:nth-child(3)')
        each_case['case_id'] = (await case_id.text_content())
        each_case['case_title'] = (await case_title.text_content())
        each_case['court_name'] = court_name
    
        ###########################
        # if index==15:
        #    break # for debugging, delete later
        ###########################    

        already_scraped_df = pd.read_csv('NASHIK_MALEGAON_pending_case_data.csv')
        already_scraped_case_ids = list(already_scraped_df['case_id'])
        if each_case['case_id'] in already_scraped_case_ids:
#             print(f"Already scraped {each_case['case_id']}")
            continue # this means go back to the top of the loop without finishing this iteration
        
        print(f"Scraping {each_case['case_id']}")
            
        time.sleep(3)
        
        #Because this case's view button acts weird, we are skipping this case
        cases_to_skip = ['Sessions Case/800040/2014']
        if each_case['case_id'] in cases_to_skip:
            with open('NASHIK_MALEGAON_pending_case_data.csv', 'a') as csvfile:
                writer = csv.DictWriter(csvfile, fieldnames=headers)
                writer.writerow(each_case)
            list_of_cases.append(each_case)
            continue
            
        #Click on view button
        view_button = await row.query_selector('a')
        await view_button.click()
            
        time.sleep(5)

        #Scrape the view contents and put them in each_case

        #case_details
        case_details_table = await page.query_selector('#CSact .case_details_table')
        case_details = await scrape_weird_first_table(case_details_table)
            #print(case_details)

        #case_status
        cases_status_table = await page.query_selector('#CSact .case_status_table')
        cases_status = await scrape_side_by_side_table(cases_status_table)
            #print(cases_status)

        #subordinate court
        lower_court_table = await page.query_selector('#CSact .Lower_court_table')
        if lower_court_table:
            lower_court = await scrape_side_by_side_table(lower_court_table)
        else:
            lower_court = {}
            print("Failed to scrape lower court table")
            #print(lower_court)

        #FIR_details
        FIR_details_table = await page.query_selector('#CSact .FIR_details_table')
        if FIR_details_table:
            FIR_details = await scrape_side_by_side_table(FIR_details_table)
        else:
            FIR_details = {}
            print("Failed to scrape FIR details table")
            #Put the result through pd.DataFrame() after looping
            #print(FIR_details)

        #petitioner_advocate
        petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
        all_trs = await petitioner_and_advocate_table.query_selector_all('tr')
        petitioner_advocate = {}
        petitioner_and_advocate = []
        for tr in all_trs:
            all_tds = await tr.query_selector_all('td')
            for td in all_tds:
                petitioner_and_advocate.append(await td.text_content())
                petitioner_advocate['petitioner_and_advocate'] = petitioner_and_advocate
                #print(petitioner_advocate)

        #respondent_advocate
        respondent_and_advocate_table = await page.query_selector('#CSact .Respondent_Advocate_table')
        all_trs = await respondent_and_advocate_table.query_selector_all('tr')
        respondent_advocate = {}
        respondent_and_advocate = []
        for tr in all_trs:
            all_tds = await tr.query_selector_all('td')
            for td in all_tds:
                respondent_and_advocate.append(await td.text_content())
                respondent_advocate['respondent_and_advocate'] = respondent_and_advocate
                #print(respondent_advocate)

        #click back button
        back_button = page.locator('#main_back_act')
        await back_button.click()
        
        time.sleep(5)
        
        all_case_data = {**each_case, **case_details, **cases_status, **lower_court, **FIR_details, **petitioner_advocate, **respondent_advocate}

        with open('NASHIK_MALEGAON_pending_case_data.csv', 'a') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=headers)
            writer.writerow(all_case_data)
            
            
            
        list_of_cases.append(all_case_data)

    else:
        raise Exception("Error parsing table. Expected 2 or 4 td elements.")
# Out:
#   0%|          | 0/129 [00:00<?, ?it/s]
# Scraping Sessions Case/800018/2011
# Failed to scrape FIR details table
# Scraping Sessions Case/800071/2010
# Failed to scrape FIR details table
# Scraping Sessions Case/800023/2010
# Failed to scrape FIR details table
# Scraping Sessions Case/800099/2009
# Failed to scrape FIR details table
# Scraping Sessions Case/800025/2008
# Failed to scrape FIR details table
# Scraping Sessions Case/800107/2003
# Failed to scrape FIR details table
# Scraping Sessions Case/800090/2002
# Failed to scrape FIR details table
# Scraping Sessions Case/800041/1997
# Failed to scrape FIR details table
# Scraping Spl.Case/46/2022
# Failed to scrape lower court table
# Scraping Cri.Rev.App./29/2022
# Failed to scrape lower court table
# Scraping Cri.Rev.App./77/2019
# Failed to scrape lower court table
# Scraping Cri.M.A./25/2022
# Failed to scrape lower court table
# Failed to scrape FIR details table
# Scraping Cri.M.A./50/2021
# Failed to scrape lower court table
# Failed to scrape FIR details table
# Scraping Atro.Spl.Case/28/2020
# Failed to scrape lower court table
# Scraping Atro.Spl.Case/7/2017
# Failed to scrape lower court table
# Scraping Cri.Bail Appln./642/2022
# Failed to scrape lower court table
# Scraping Cri.Bail Appln./641/2022
# Failed to scrape lower court table
# Scraping Cri.Bail Appln./638/2022
# Failed to scrape lower court table
# Scraping Cri.Bail Appln./588/2022
# Failed to scrape lower court table
# Scraping Cri.M.A./1324/2021
# Failed to scrape lower court table
# Failed to scrape FIR details table
# Scraping Cri.M.A./5699/2020
# Failed to scrape lower court table
# Failed to scrape FIR details table
# Scraping Cri.M.A./1000033/2003
# Failed to scrape lower court table
# Failed to scrape FIR details table
# Scraping R.C.C./782/2022
# Failed to scrape lower court table
# Scraping R.C.C./704/2022
# Failed to scrape lower court table
# Scraping R.C.C./693/2022
# Failed to scrape lower court table
# Scraping R.C.C./364/2022
# Failed to scrape lower court table
# Scraping R.C.C./695/2021
# Failed to scrape lower court table
# Scraping R.C.C./84/2020
# Failed to scrape lower court table

# %%
data_so_far = pd.read_csv('pending_case_data.csv')
data_so_far.to_csv(f'pending_case_data_{pd.Timestamp.now()}.csv')

# %%
#df.to_csv('MAH_pending_302.csv', index=False)

# %%
#pd.read_csv('MAH_pending_302.csv')

# %%
#SAFEKEEPING

# view_button = await page.locator('//*[@id="dispTable"]/tbody/tr[2]/td[4]/a').click()
# #case_details
# case_details_table = await page.query_selector('#CSact .case_details_table')
# case_details = await scrape_weird_first_table(case_details_table)
# print(case_details)

# #case_status
# cases_status_table = await page.query_selector('#CSact .case_status_table')
# cases_status = await scrape_side_by_side_table(cases_status_table)
# print(cases_status)

# #subordinate court
# lower_court_table = await page.query_selector('#CSact .Lower_court_table')
# lower_court = await scrape_side_by_side_table(lower_court_table)
# print(lower_court)

# #FIR_details
# FIR_details_table = await page.query_selector('#CSact .FIR_details_table')
# FIR_details = await scrape_side_by_side_table(FIR_details_table)
# #Put the result through pd.DataFrame() after looping
# print(FIR_details)

# #petitioner_advocate
# petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
# all_trs = await petitioner_and_advocate_table.query_selector_all('tr')
# petitioner_advocate = {}
# petitioner_and_advocate = []
# for tr in all_trs:
#     all_tds = await tr.query_selector_all('td')
#     for td in all_tds:
#         petitioner_and_advocate.append(await td.text_content())
#         petitioner_advocate['petitioner_and_advocate'] = petitioner_and_advocate
#     print(petitioner_advocate)
    
# #respondent_advocate
# respondent_and_advocate_table = await page.query_selector('#CSact .Respondent_Advocate_table')
# all_trs = await respondent_and_advocate_table.query_selector_all('tr')
# respondent_advocate = {}
# respondent_and_advocate = []
# for tr in all_trs:
#     all_tds = await tr.query_selector_all('td')
#     for td in all_tds:
#         respondent_and_advocate.append(await td.text_content())
#         respondent_advocate['respondent_and_advocate'] = respondent_and_advocate
#     print(respondent_advocate)

# %%
#back_button = await page.locator('//*[@id="main_back_act"]').click()

# %%
#List of tables for reference and mental health

# case_details_table = await page.query_selector('#CSact .case_details_table')
# cases_status_table = await page.query_selector('#CSact .case_status_table')
# petitioner_and_advocate_table = await page.query_selector('#CSact .Petitioner_Advocate_table')
# respondent_and_advocate_table = await page.query_selector('#CSact .Respondent_Advocate_table')
# acts_table = await page.query_selector('#CSact .acts_table')
# lower_court_table = await page.query_selector('#CSact .Lower_court_table')
# FIR_details_table = await page.query_selector('#CSact .FIR_details_table')

# %%
# collect dictionaries for each table
# case_details_data = scrape_weird_first_table(case_details_table)
# case_status_data = scrape_side_by_side_table(case_status_table)

# # combine dictionaries
# case_data = {**case_details_data, **case_status_data}

# %% [markdown]
# ### case_details_table

# %%
case_details_table = await page.query_selector('#CSact .case_details_table')
case_details = await scrape_weird_first_table(case_details_table)
print(case_details)

# %% [markdown]
# ### cases_status_table

# %%
cases_status_table = await page.query_selector('#CSact .case_status_table')
cases_status = await scrape_side_by_side_table(cases_status_table)
print(cases_status)

# %% [markdown]
# ### lower_court_table

# %%
lower_court_table = await page.query_selector('#CSact .Lower_court_table')
lower_court = await scrape_side_by_side_table(lower_court_table)
print(lower_court)

# %% [markdown]
# ### FIR_details_table

# %%
FIR_details_table = await page.query_selector('#CSact .FIR_details_table')
FIR_details = await scrape_side_by_side_table(FIR_details_table)
#Put the result through pd.DataFrame() after looping
print(FIR_details)

# %% [markdown]
# ### acts_table

# %%
acts_table = await page.query_selector('#CSact .acts_table')
acts = await scrape_dataframe_style_table(acts_table)
print(acts)
